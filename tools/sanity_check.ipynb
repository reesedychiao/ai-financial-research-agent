# %%
from data_fetcher import fetch_market_data

data = fetch_market_data("AAPL", "2025-12-01", "2025-12-10")
# Out:
# /Users/reesedychiao/Desktop/ai-financial-research-agent/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[1], line 3
#       1 from data_fetcher import fetch_market_data
# ----> 3 data = fetch_market_data("AAPL", "2025-12-01", "2025-12-10")
#
# File ~/Desktop/ai-financial-research-agent/tools/data_fetcher.py:9, in fetch_market_data(ticker, start, end)
#       5 def fetch_market_data(ticker: str, start: str, end: str) -> pd.DataFrame:
#       6     """
#       7     Fetch historical price data.
#       8     """
# ----> 9     data = yf.Ticker(ticker).history(start=start, end=end)
#      10     if data.empty:
# ...

# %%
import pandas as pd

data = pd.read_csv('../data/raw/AAPL_2025-12-01_2025-12-10.csv')

# %%
from feature_engineer import engineer_features

data = engineer_features(data, window=3)
# Out:
# Feature engineering complete!
#        returns  volatility  cumulative_return
# count   4.0000      4.0000             4.0000
# mean   -0.0062      0.0055            -0.0158
# std     0.0044      0.0045             0.0054
# min    -0.0121      0.0023            -0.0209
# 25%    -0.0082      0.0028            -0.0190
# 50%    -0.0050      0.0037            -0.0168
# 75%    -0.0030      0.0064            -0.0136
# max    -0.0026      0.0121            -0.0085

# %%
from analysis import run_baseline_model

run_baseline_model(data)
# Out:
# {'metrics': {'Average Daily Return': np.float64(-0.006182243007205712),
#   'Return Volatility (Std Dev)': np.float64(0.004398484809148653),
#   'Cumulative Return': np.float64(-0.02452930272890419),
#   'Trend Slope (Returns vs Time)': np.float64(0.0032406756671558667),
#   'Trend R²': 0.9047189629021157},
#  'summary':                                   Value
#  Average Daily Return          -0.006182
#  Return Volatility (Std Dev)    0.004398
#  Cumulative Return             -0.024529
#  Trend Slope (Returns vs Time)  0.003241
#  Trend R²                       0.904719,
#  'model': LinearRegression()}
